# %%
import numpy as np
data1=np.load ('F:/Data/Data_music_NP/119405.npy')

# %%
print(data1.shape)
def Channels_mel(input_mel):
    
    if input_mel.shape[1]<128*3:
        num=128*3//input_mel.shape[1]
        num+=1
        output_mel= np.concatenate([input_mel] * num, axis=1)
    output_mel=output_mel[:,:128*3].reshape(128,3,128).transpose(1,0,2)
    return output_mel
print(Channels_mel(data1).shape)
# Out:
# (128, 195)
# (3, 128, 128)

# %%
import os
folder_path = 'F:/Data/Data_music_NP'

file_names = os.listdir(folder_path)
for file_name in file_names:
    inputfile=os.path.join(folder_path,file_name)
    if np.load(inputfile).shape[1] <128*2:
        print(file_name)
# Out:
# 117414.npy
# 119405.npy

# %%
import numpy as np

# 创建一个（128，356）的矩阵
original_matrix = np.random.rand(5, 7)

# 指定复制次数
num_copies = 2

# 复制并拼接
expanded_matrix = np.concatenate([original_matrix] * num_copies, axis=1)

print("原始矩阵的形状:", original_matrix)  # 输出：(128, 356)
print("扩展后的矩阵的形状:", expanded_matrix)  # 输出：(128, 356*3)

print(expanded_matrix[:,:12].reshape(5,3,4).transpose(1,0,2))
# Out:
# 原始矩阵的形状: [[0.8997954  0.76660641 0.12413849 0.64568257 0.92741557 0.39194351
#   0.44238985]
#  [0.5381525  0.41842256 0.52094415 0.07648208 0.1050832  0.1383393
#   0.12411165]
#  [0.23253573 0.52337927 0.82012173 0.96544354 0.33992102 0.47278914
#   0.41273731]
#  [0.10168508 0.53061547 0.57801549 0.34029712 0.98454154 0.45210592
#   0.74413677]
#  [0.37280513 0.76903738 0.50765644 0.97861698 0.81391851 0.13689729
#   0.8937581 ]]
# 扩展后的矩阵的形状: [[0.8997954  0.76660641 0.12413849 0.64568257 0.92741557 0.39194351
#   0.44238985 0.8997954  0.76660641 0.12413849 0.64568257 0.92741557
#   0.39194351 0.44238985]
#  [0.5381525  0.41842256 0.52094415 0.07648208 0.1050832  0.1383393
#   0.12411165 0.5381525  0.41842256 0.52094415 0.07648208 0.1050832
#   0.1383393  0.12411165]
#  [0.23253573 0.52337927 0.82012173 0.96544354 0.33992102 0.47278914
#   0.41273731 0.23253573 0.52337927 0.82012173 0.96544354 0.33992102
#   0.47278914 0.41273731]
# ...

# %%
def Channels_mel(input_mel):
    
    if input_mel.shape[1]<128*3:
        num=128*3//input_mel.shape[1]
        num+=1
        output_mel= np.concatenate([input_mel] * num, axis=1)
    output_mel=output_mel[:,:128*3].reshape(128,3,128).transpose(1,0,2)
    return output_mel
